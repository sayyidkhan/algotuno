# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('AAPL.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1259 non-null   object
#  1   Open        1259 non-null   float64
#  2   High        1259 non-null   float64
#  3   Low         1259 non-null   float64
#  4   Close       1259 non-null   float64
#  5   Adj Close   1259 non-null   float64
#  6   Volume      1259 non-null   int64
#  7   New_Open    1259 non-null   float64
#  8   Difference  1259 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 88.6+ KB

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'New_Open', 'Difference'],
#       dtype='object')

# %%
dfNoDate = df.drop('Date', axis=1)

# %%
dfNoDate.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'New_Open',
#        'Difference'],
#       dtype='object')

# %%
np.mean(df[['Difference']])
# Out:
# Difference    0.092607
# dtype: float64

# %%
dfDiff = df[['Difference']]

# %%
dfDiff.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Difference'}>]], dtype=object)

# %%
import statistics

# %%
mean = statistics.mean(dfDiff['Difference'])
sd = statistics.stdev(dfDiff['Difference'])

# %%
from scipy.stats import norm
plt.plot(dfDiff['Difference'], norm.pdf(dfDiff['Difference'], mean, sd))
plt.show()

# %%
sd
# Out:
# 1.9494653600869856

# %%
mean
# Out:
# 0.0926072271644162

# %%
dfDiff.head()
# Out:
#    Difference
# 0   -0.295002
# 1    0.562500
# 2    0.327500
# 3   -0.017498
# 4   -0.584999

# %%
conditions1 = [
    (dfDiff['Difference'] <= -3.8),
    (dfDiff['Difference'] < -1.9) & (dfDiff['Difference'] > -3.8),
    (dfDiff['Difference'] <=0) & (dfDiff['Difference'] > -1.9),
    (dfDiff['Difference'] > 0) & (dfDiff['Difference'] < 1.9),
    (dfDiff['Difference'] > 1.9) & (dfDiff['Difference'] <3.8),
    (dfDiff['Difference'] >= 3.8)
    ]

# %%
conditions = [
    (dfDiff['Difference'] <= -3.5),
    (dfDiff['Difference'] < -3.0) & (dfDiff['Difference'] > -3.5),
    (dfDiff['Difference'] < -2.5) & (dfDiff['Difference'] > -3.0),
    (dfDiff['Difference'] < -2.0) & (dfDiff['Difference'] > -2.5),
    (dfDiff['Difference'] < -1.5) & (dfDiff['Difference'] > -2.0),
    (dfDiff['Difference'] <-1.0) & (dfDiff['Difference'] > -1.5),
    (dfDiff['Difference'] <-0.5) & (dfDiff['Difference'] > -1.0),
    (dfDiff['Difference'] <=0) & (dfDiff['Difference'] > -0.5),
    (dfDiff['Difference'] > 0) & (dfDiff['Difference'] < 0.5),
    (dfDiff['Difference'] > 0.5) & (dfDiff['Difference'] < 1.0),
    (dfDiff['Difference'] > 1.0) & (dfDiff['Difference'] < 1.5),
    (dfDiff['Difference'] > 1.5) & (dfDiff['Difference'] < 2.0),
    (dfDiff['Difference'] > 2.0) & (dfDiff['Difference'] < 2.5),
    (dfDiff['Difference'] > 2.5) & (dfDiff['Difference'] < 3.0),
    (dfDiff['Difference'] > 3.0) & (dfDiff['Difference'] < 3.5),
    (dfDiff['Difference'] >= 3.5)
    ]

# %%
values = ['n8h', 'n7s', 'n6h', 'n5h', 'n4h', 'n3h','n2h', 'n1sh', 'p1h','p2h', 'p3h', 'p4h','p5h', 'p6h', 'p7h', 'p8h']

# %%
df['deviation'] = np.select(conditions, values)

# %%
df.head()
dfNoDate = df.drop('Date', axis=1)

# %%
from sklearn.model_selection import train_test_split
X=dfNoDate.drop('deviation', axis=1)
y=dfNoDate['deviation']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
dfNoDate.head()
# Out:
#         Open       High        Low      Close  Adj Close     Volume  \
# 0  38.407501  38.485001  38.027500  38.314999  36.122414  103222800
# 1  38.112499  38.517502  38.077499  38.487499  36.434811  109020400
# 2  38.674999  39.105000  38.667500  39.025002  36.943649  130108000
# 3  39.002499  39.162498  38.762501  38.924999  36.848976  104038800
# 4  38.985001  39.014999  38.680000  38.867500  36.794544   80194000
#
#     New_Open  Difference deviation
# 0  38.112499   -0.295002       n1s
# 1  38.674999    0.562500       p1s
# 2  39.002499    0.327500       p1s
# 3  38.985001   -0.017498       n1s
# 4  38.400002   -0.584999       n1s

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=128)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=128)

# %%
rfc_pred = rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,rfc_pred))
print(classification_report(y_test, rfc_pred))
# Out:
# [[138   1   0   2   0   0]
#  [  5   8   0   0   0   0]
#  [  0   1  11   0   0   0]
#  [  0   0   0 172   2   0]
#  [  0   0   0   2  26   0]
#  [  0   0   0   0   3   7]]
#               precision    recall  f1-score   support
#
#          n1s       0.97      0.98      0.97       141
#          n2s       0.80      0.62      0.70        13
#          n3s       1.00      0.92      0.96        12
#          p1s       0.98      0.99      0.98       174
#          p2s       0.84      0.93      0.88        28
#          p3s       1.00      0.70      0.82        10
#
#     accuracy                           0.96       378
#    macro avg       0.93      0.85      0.89       378
# weighted avg       0.96      0.96      0.96       378

# %%
df_pred = pd.read_csv('AAPL_pred.csv')

# %%
rfc_pred = rfc.predict(df_pred)

# %%
rfc_pred
# Out:
# array(['p1s'], dtype=object)
